# %% [markdown]
# When API app is runned on Terminal, it is running on 'http://127.0.0.1:8000/'
#
# ![image.png](attachment:image.png)
#
# For both API hit , http code is 200(means sucessfull)

# %% [markdown]
# Now when we checked this URL ,we got yhis -
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now using FAST API , we can look into documentation easily -
#
# Just hit URL -'http://127.0.0.1:8000/docs' & see the documentation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now to check 'POST' method , we can check it from browser only in FASTAPI.
# - Click on 'Try it out' in Post method, then give inputs in 'Request Body'
#
# ![image.png](attachment:image.png)
#
# Just Below that Response will be shown
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# As usual for every API hit - http code will be displayed in terminal
#
# ![image.png](attachment:image.png)
